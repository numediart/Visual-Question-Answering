# %%
# !pip install torch==1.1.0
# !pip install torchvision==0.2.2
# !pip install pillow
# !pip install tqdm
# Out:
# ...
#      |████████████████████████████████| 71kB 4.7MB/s
# ...
#      |████████████████████████████████| 61kB 31.0MB/s
# ...
#   Found existing installation: tqdm 4.28.1
#     Uninstalling tqdm-4.28.1:
#       Successfully uninstalled tqdm-4.28.1
#   Found existing installation: torchvision 0.3.0
#     Uninstalling torchvision-0.3.0:
#       Successfully uninstalled torchvision-0.3.0
# ...

# %%
# !git clone https://github.com/numediart/Visual-Question-Answering.git
# Out:
# Cloning into 'Visual-Question-Answering'...
# remote: Enumerating objects: 47, done.
# remote: Counting objects: 100% (47/47), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 47 (delta 11), reused 22 (delta 2), pack-reused 0
# Unpacking objects: 100% (47/47), done.

# %%
cd Visual-Question-Answering/
# Out:
# /content/Visual-Question-Answering

# %%
# !unzip data/data.zip -d data
# Out:
# Archive:  data/data.zip
#    creating: data/cache/
#   inflating: data/cache/train_target.pkl
#   inflating: data/cache/trainval_ans2label.pkl
#   inflating: data/cache/trainval_label2ans.pkl
#   inflating: data/cache/val_target.pkl
#   inflating: data/dictionary.pkl
#   inflating: data/glove6b_init_300d.npy
#   inflating: data/train36_imgid2idx.pkl
#   inflating: data/train_ids.pkl
#   inflating: data/v2_OpenEnded_mscoco_test-dev2015_questions.json
#   inflating: data/v2_OpenEnded_mscoco_test2015_questions.json
#   inflating: data/v2_OpenEnded_mscoco_train2014_questions.json
#   inflating: data/v2_OpenEnded_mscoco_val2014_questions.json
#   inflating: data/v2_mscoco_train2014_annotations.json
#   inflating: data/v2_mscoco_val2014_annotations.json

# %%
from IPython.display import Image
Image('example.jpg', width=200)

# %%
# !python main.py --inference True \
		--ckpt ckpt/model_0.5590.pth \
		--image example.jpg \
		--question "What is the man holding ?"
# Out:
# Output dir is ckpt
# loading dictionary from data/dictionary.pkl
# Downloading: "https://download.pytorch.org/models/resnet50-19c8e357.pth" to /root/.cache/torch/checkpoints/resnet50-19c8e357.pth
# 100% 102502400/102502400 [00:00<00:00, 143027169.29it/s]
# Question: What is the man holding ?
# Answer: banana

# %%
# !python main.py --inference True \
		--ckpt ckpt/model_0.5590.pth \
		--image example.jpg \
		--question "What is the color of the man's hair ?"
# Out:
# Output dir is ckpt
# loading dictionary from data/dictionary.pkl
# Question: What is the color of the man's hair ?
# Answer: brown

# %%
# !python main.py --inference True \
		--ckpt ckpt/model_0.5590.pth \
		--image example.jpg \
		--question "Is the man handsome and smart ?"
# Out:
# Output dir is ckpt
# loading dictionary from data/dictionary.pkl
# Question: Is the man handsome and smart ?
# Answer: yes
